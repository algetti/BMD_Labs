# %% [markdown]
# <h2>Комп'ютерний практикум №1 з предмету "Обробка та аналіз біомедичних даних"</h2>
#    <h3><small>Студентки групи БС-81</small></h3>
#    <h3>Кумпан Ліни</h3>

# %%
import pandas as pd

# %%
test_df = pd.DataFrame({
    "City": ["Kyiv","Kyiv","Kharkiv", "Brovary","Poltava"],
    "Name of dance-centre": ["Topone", "Myway", "Sharm", "Art people", "SHH"],
    "Dance styles": ["Hip hop","Choreo", "Contemporary","Jazz funk","Jazz Modern"],
    "Number of visitors on month": [12000, 15000,8000,9000,5500],
    "Number of competitions won": [28,59,21,16,13],
    "level": ["Professional", "Professional", 
               "Average", "Average", " Beginner"]
})
test_df
# Out:
#       City Name of dance-centre  Dance styles  Number of visitors on month  \
# 0     Kyiv               Topone       Hip hop                        12000
# 1     Kyiv                Myway        Choreo                        15000
# 2  Kharkiv                Sharm  Contemporary                         8000
# 3  Brovary           Art people     Jazz funk                         9000
# 4  Poltava                  SHH   Jazz Modern                         5500
#
#    Number of competitions won         level
# 0                          28  Professional
# 1                          59  Professional
# 2                          21       Average
# 3                          16       Average
# 4                          13      Beginner

# %%
path = "E:/Anaconda3_64/Scripts/Untitled_Folder/StudentsPerformance.csv"
data = pd.read_csv(path, encoding = "UTF-8")

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os

print(f"Current dir: {os.getcwd()}")
# Out:
# Current dir: E:\Anaconda3_64\Scripts\Untitled_Folder

# %%
data = pd.read_csv("StudentsPerformance.csv")

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data["gender"].describe()
# Out:
# count       1000
# unique         2
# top       female
# freq         518
# Name: gender, dtype: object

# %%
data["reading score"].describe()
# Out:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64

# %%
slice = data.iloc[0:10, :]

slice
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
new_column = ["first_group" if x < 6 else "second_group" for x in range(10)]

slice.insert(3, "Group", new_column)
slice
# Out:
#    gender race/ethnicity parental level of education         Group  \
# 0  female        group B           bachelor's degree   first_group
# 1  female        group C                some college   first_group
# 2  female        group B             master's degree   first_group
# 3    male        group A          associate's degree   first_group
# 4    male        group C                some college   first_group
# 5  female        group B          associate's degree   first_group
# 6  female        group B                some college  second_group
# 7    male        group B                some college  second_group
# 8    male        group D                 high school  second_group
# 9  female        group B                 high school  second_group
#
#           lunch test preparation course  math score  reading score  \
# 0      standard                    none          72             72
# 1      standard               completed          69             90
# ...

# %%
slice.groupby("Group").describe()
# Out:
#              math score                                                      \
#                   count       mean        std   min   25%   50%   75%   max
# Group
# first_group         6.0  70.833333  13.905634  47.0  69.5  71.5  75.0  90.0
# second_group        4.0  57.500000  23.515952  38.0  39.5  52.0  70.0  88.0
#
#              reading score             ...              writing score  \
#                      count       mean  ...    75%   max         count
# Group                                  ...
# first_group            6.0  79.166667  ...  88.25  95.0           6.0
# second_group           4.0  65.500000  ...  71.75  95.0           4.0
#
#
#                    mean        std   min    25%   50%    75%   max
# Group
# first_group   75.333333  17.107503  44.0  74.25  76.5  85.50  93.0
# second_group  62.000000  23.079572  39.0  47.25  58.5  73.25  92.0
#
# [2 rows x 24 columns]

# %%
slice.to_csv("output.csv", encoding = "UTF-8")

# %%
data.describe().to_csv("satistics.csv", encoding = 'UTF-8')
